# %%
import numpy as np
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt

gdp_file = '..\data\gdp_perCapita.csv'

df = pd.read_csv(gdp_file, sep=',', usecols=['geo', 'TIME_PERIOD', 'OBS_VALUE']).rename(columns={
    "geo":"state", "TIME_PERIOD": "year", "OBS_VALUE":"GDP" })

dfPivoted = df.pivot(index='year', columns='state', values='GDP')
dfPctChange = dfPivoted.pct_change() * 100  

mean = dfPivoted.mean(axis=1)

sea.set_theme(style="white")
for state in dfPivoted.columns:
    sea.lineplot(x=dfPivoted.index, y=dfPivoted[state], color="lightgray" , linewidth=1, label=None)
sea.lineplot(data=mean, color="red", linewidth=2.5, label="Media")

plt.legend(handles=[
    plt.Line2D([0], [0], color='lightgray', lw=2, label='Stati'),
    plt.Line2D([0], [0], color='red', lw=2.5, label='Media')],
    loc='upper right', bbox_to_anchor=(1.25, 1))

plt.ylabel(None)
plt.xlabel(None)
dfPctChange.mean().mean()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\pietr\AppData\Local\Temp\ipykernel_19160\1343344325.py:6: SyntaxWarning: invalid escape sequence '\d'
#   gdp_file = '..\data\gdp_perCapita.csv'
# np.float64(2.3671792620723795)
